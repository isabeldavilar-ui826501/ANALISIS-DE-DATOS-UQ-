# %% [markdown]
# INDICADORES DE MERCADO LABORAL MEDIANTE LA METODOLOGIA DANE: EXPLORACION Y ANALISIS
# DESCRIPTIVO DE LOS RESULTADOS DE LA GEIH 2025 (DICIEMBRE)

# %% [markdown]
# IMPORTANDO LIBRERIA

# %%
import pandas as pd 
import numpy as np
